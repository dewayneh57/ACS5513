# %% [markdown]
# <a href="https://colab.research.google.com/github/dewayneh57/ACS5513/blob/main/ACS_5513_Zillow_Research_Home_Value_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import numpy as np
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter
import matplotlib.pyplot as plt
from scipy import stats

# options
pd.set_option("display.max_columns", None)

# file path set to Google Drive 'Colab Notebooks > Housing Data > Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv
file_path = "/content/drive/MyDrive/Colab Notebooks/Housing Data/Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"

# create dataframe loading file_path
df = pd.read_csv(file_path)

df.head(20)
# Out:
#     RegionID  SizeRank             RegionName    RegionType StateName State  \
# 0     112345         0               Maryvale  neighborhood        AZ    AZ
# 1     192689         1               Paradise  neighborhood        NV    NV
# 2     270958         2        Upper West Side  neighborhood        NY    NY
# 3     270957         3        Upper East Side  neighborhood        NY    NY
# 4     118208         4      South Los Angeles  neighborhood        CA    CA
# 5     192796         5          Spring Valley  neighborhood        NV    NV
# 6     194430         6          East New York  neighborhood        NY    NY
# 7     272902         7     Bedford-Stuyvesant  neighborhood        NY    NY
# 8     268496         8  Southeast Los Angeles  neighborhood        CA    CA
# 9     192820         9          Sunrise Manor  neighborhood        NV    NV
# 10    111818        10            Deer Valley  neighborhood        AZ    AZ
# ...
